# %%
import numpy as np
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
# %matplotlib inline
from bokeh.plotting import figure
from bokeh.io import show, output_notebook
from bokeh.charts import Bar

# %% [markdown]
# https://data.world/data-society/airlines-delay <br>
# https://gist.github.com/omarish/5687264 <br>
# https://data.world/data-society/hospital-charge-data <br>
# https://data.world/nrippner/cluster-analysis-challenge <br>
# https://data.world/uci/open-university-learning-analytics-dataset

# %%
airline_delay = pd.read_csv('./data/airlinedelaycauses_DelayedFlights.csv')
airline_delay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1936758 entries, 0 to 1936757
# Data columns (total 30 columns):
# Unnamed: 0           int64
# Year                 int64
# Month                int64
# DayofMonth           int64
# DayOfWeek            int64
# DepTime              float64
# CRSDepTime           int64
# ArrTime              float64
# CRSArrTime           int64
# UniqueCarrier        object
# FlightNum            int64
# TailNum              object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin               object
# Dest                 object
# Distance             int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled            int64
# CancellationCode     object
# Diverted             int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# ...

# %%
msno.matrix(airline_delay)

# %%
data_auto = pd.read_csv('./data/mpg.csv')

# %%
msno.matrix(data_auto)

# %%
data_auto.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year  origin                       name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
test = pd.read_csv('./data/oulad/assessments.csv')
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 6 columns):
# code_module          206 non-null object
# code_presentation    206 non-null object
# id_assessment        206 non-null int64
# assessment_type      206 non-null object
# date                 206 non-null object
# weight               206 non-null float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.7+ KB

# %%
p = figure(plot_width = 600, plot_height = 600, title = 'Example Glyphs', x_axis_label = 'X', y_axis_label = 'Y')

# Example data
squares_x = [1, 3, 4, 5, 8]
squares_y = [8, 7, 3, 1, 10]
circles_x = [9, 12, 4, 3, 15]
circles_y = [8, 4, 11, 6, 10]

# Add squares glyph
# p.square(test.assessment_type, test.weight, size = 12, color = 'navy', alpha = 0.6)
# Add circle glyph
# p.circle(circles_x, circles_y, size = 12, color = 'red')

p = Bar(airline_delay, 'UniqueCarrier', values= 'ArrDelay', group = 'Dest', agg = 'mean')

# Set to output the plot in the notebook
output_notebook()
# Show the plot
show(p)
